# %% [markdown]
# <a href="https://colab.research.google.com/github/josiahtr/MISY262-Team-3-Final-Project/blob/main/MISY262_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Some sources:**
# Linear regression outline: https://www.kaggle.com/sudhirnl7/linear-regression-tutorial <br>
# Changing working directory to gdrive folder: https://newbedev.com/google-colab-changing-directory <br>
# Missing vals visualization: https://www.geeksforgeeks.org/python-visualize-missing-values-nan-values-using-missingno-library/

# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/'
# /content

# %%
# !pwd
# Out:
# /content

# %%
#importing the os module
import os
os.chdir('/content/gdrive/MyDrive/MISY262')

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/MISY262

# %%
# Import dataset
#path ='dataset/'
df = pd.read_csv('rideshare_kaggle.csv')
print('\nNumber of rows and columns in the data set: ',df.shape)
print('')

#Lets look into top few rows and columns in the dataset
df.head()
# Out:
# Number of rows and columns in the data set:  (693071, 57)
#                                      id  ...  apparentTemperatureMaxTime
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  ...                  1544958000
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  ...                  1543251600
# 2  981a3613-77af-4620-a42a-0c0866077d1e  ...                  1543320000
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  ...                  1543510800
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  ...                  1543420800
#
# [5 rows x 57 columns]

# %%
df.tail()
# Out:
#                                           id  ...  apparentTemperatureMaxTime
# 693066  616d3611-1820-450a-9845-a9ff304a4842  ...                  1543690800
# 693067  633a3fc3-1f86-4b9e-9d48-2b7132112341  ...                  1543690800
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f  ...                  1543690800
# 693069  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e  ...                  1543690800
# 693070  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda  ...                  1543690800
#
# [5 rows x 57 columns]

# %%
#names of columns
df.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'apparentTemperature', 'short_summary', 'long_summary',
#        'precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
#        'windGust', 'windGustTime', 'visibility', 'temperatureHigh',
#        'temperatureHighTime', 'temperatureLow', 'temperatureLowTime',
#        'apparentTemperatureHigh', 'apparentTemperatureHighTime',
#        'apparentTemperatureLow', 'apparentTemperatureLowTime', 'icon',
#        'dewPoint', 'pressure', 'windBearing', 'cloudCover', 'uvIndex',
#        'visibility.1', 'ozone', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensityMax', 'uvIndexTime', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
# ...

# %%
#info on columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           693071 non-null  object
#  1   timestamp                    693071 non-null  float64
#  2   hour                         693071 non-null  int64
#  3   day                          693071 non-null  int64
#  4   month                        693071 non-null  int64
#  5   datetime                     693071 non-null  object
#  6   timezone                     693071 non-null  object
#  7   source                       693071 non-null  object
#  8   destination                  693071 non-null  object
#  9   cab_type                     693071 non-null  object
#  10  product_id                   693071 non-null  object
#  11  name                         693071 non-null  object
# ...

# %%
#number of rows
len(df)
# Out:
# 693071

# %%
#some basic stats for each of the columns
df.describe()
# Out:
#           timestamp  ...  apparentTemperatureMaxTime
# count  6.930710e+05  ...                6.930710e+05
# mean   1.544046e+09  ...                1.544048e+09
# std    6.891925e+05  ...                6.910777e+05
# min    1.543204e+09  ...                1.543187e+09
# 25%    1.543444e+09  ...                1.543439e+09
# 50%    1.543737e+09  ...                1.543788e+09
# 75%    1.544828e+09  ...                1.544818e+09
# max    1.545161e+09  ...                1.545109e+09
#
# [8 rows x 46 columns]

# %%
#Checking for missing values
df.isna().sum()
#That's a lot of missing values in price!
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          55095
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# ...

# %%
# Program to visualize missing values in dataset
  
# Importing the libraries
import pandas as pd
import missingno as msno
  
# Visualize the number of missing
# values as a bar chart
msno.bar(df)
#From this chart, we can see that, entirely, the number of missing values comes from the 'price' feature

# %% [markdown]
# **Further exploration:** is there any correllation with these missing price values and other features? (Like do Uber Taxis for example just not provide price easily) How could we check for that? <br>
# <br>
# Also, we'll have to find a way to statistically drop these values before we get into the linear regression <br>
# <br>
# **Project questions:** Will we need to do any sort of filtering? Like would it be best to create two linear regression models, one for Lyft and one for Uber, and compare? Or be best to create one model that can accurately predict when and where to get the best price across the two? <br>
# <br>
# Could surge rate be something to look into especially? Could be something to research - is this something independently based on one system factor such as volume, or is it a product of numorous factors such as time, location, weather, etc, that influences price hand-in-hand? <br> - Josiah

# %%
df = df.dropna()
# Clean the data. The dataset contains a few unknown values.

# %%
df.isna().sum()
# Out:
# id                             0
# timestamp                      0
# hour                           0
# day                            0
# month                          0
# datetime                       0
# timezone                       0
# source                         0
# destination                    0
# cab_type                       0
# product_id                     0
# name                           0
# price                          0
# distance                       0
# surge_multiplier               0
# latitude                       0
# longitude                      0
# temperature                    0
# apparentTemperature            0
# short_summary                  0
# long_summary                   0
# precipIntensity                0
# precipProbability              0
# humidity                       0
# windSpeed                      0
# windGust                       0
# windGustTime                   0
# visibility                     0
# ...

# %%
#Separating Uber and Lyft Data into two datasets
dfU = df[df['cab_type'] == 'Uber']
dfU
# Out:
#                                           id  ...  apparentTemperatureMaxTime
# 12      009e9c53-074d-43cf-aef2-0fbc7a47ed3d  ...                  1543611600
# 13      23f145da-f0c1-4d1f-a184-496bc003a7db  ...                  1544734800
# 14      357559cb-8c58-4278-a41a-e33b2e0997a3  ...                  1544734800
# 15      50ef1165-9d23-416c-a65c-18906207b295  ...                  1544986800
# 16      91c4861c-1780-42b0-bca1-bbd64a422cc3  ...                  1544734800
# ...                                      ...  ...                         ...
# 693065  353e6566-b272-479e-a9c6-98bd6cb23f25  ...                  1543690800
# 693066  616d3611-1820-450a-9845-a9ff304a4842  ...                  1543690800
# 693067  633a3fc3-1f86-4b9e-9d48-2b7132112341  ...                  1543690800
# 693069  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e  ...                  1543690800
# 693070  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda  ...                  1543690800
#
# [330568 rows x 57 columns]

# %%
dfL = df[df['cab_type'] == 'Lyft']
dfL
# Out:
#                                           id  ...  apparentTemperatureMaxTime
# 0       424553bb-7174-41ea-aeb4-fe06d4f4b9d7  ...                  1544958000
# 1       4bd23055-6827-41c6-b23b-3c491f24e74d  ...                  1543251600
# 2       981a3613-77af-4620-a42a-0c0866077d1e  ...                  1543320000
# 3       c2d88af2-d278-4bfd-a8d0-29ca77cc5512  ...                  1543510800
# 4       e0126e1f-8ca9-4f2e-82b3-50505a09db9a  ...                  1543420800
# ...                                      ...  ...                         ...
# 693042  086e7cda-2b2d-4736-9d5f-0cd234e04e63  ...                  1543438800
# 693043  177a946d-c7c8-4334-a97a-a8a48efb1bc0  ...                  1543438800
# 693048  871dc1be-d51e-4334-9217-1a6cd00d5058  ...                  1543438800
# 693051  aa4e5808-7357-49d3-b539-bd04d4815665  ...                  1543438800
# 693053  ac039a91-1ca0-4210-b354-32c1e173213f  ...                  1543438800
#
# [307408 rows x 57 columns]
